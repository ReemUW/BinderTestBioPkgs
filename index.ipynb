# %% [markdown]
# # Example R script

# %% [markdown]
# ##  Do some math

# %%
a <- 3

# %%
b <- 6

# %%
a + b
# Out:
# [1] 9

# %% [markdown]
# ## Add a plot

# %%
# Example from http://www.endmemo.com/program/R/plot.php

x <- c(-2,-0.3,1.4,2.4,4.5)
y <- c(5,-0.5,8,2,11)
par(mar = c(5, 1, 1, 1))
plot(x,y,type="l",col="blue",xlab="Advertise Change",ylab="Revenue Change", main="Financial Analysis")
# Out:
# Plot with title “Financial Analysis”

# %% [markdown]
# ## Create a heatmap

# %%
# Example from https://www.r-bloggers.com/how-to-make-a-simple-heatmap-in-ggplot2/

library(ggplot2)

#------------------
# CREATE DATA FRAME
#------------------
df.team_data <- expand.grid(teams = c("Team A", "Team B", "Team C", "Team D")
                           ,metrics = c("Metric 1", "Metric 2", "Metric 3", "Metric 4", "Metric 5")
                           )

# add variable: performance
set.seed(41)
df.team_data$performance <- rnorm(nrow(df.team_data))

#inspect
head(df.team_data)



#---------------------------
# PLOT: heatmap
# - here, we use geom_tile()
#---------------------------

ggplot(data = df.team_data, aes(x = metrics, y = teams)) +
  geom_tile(aes(fill = performance))
# Out:
#   teams  metrics  performance
# 1 Team A Metric 1 -0.7943683
# 2 Team B Metric 1  0.1972575
# 3 Team C Metric 1  1.0017043
# 4 Team D Metric 1  1.2888254
# 5 Team A Metric 2  0.9057534
# 6 Team B Metric 2  0.4936675
# plot without title
